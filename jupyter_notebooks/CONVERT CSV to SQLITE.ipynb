# %%
from sqlalchemy import create_engine, Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Define our country table
class Country(Base):
    __tablename__ = 'countries'
    id = Column(Integer, primary_key=True)
    country = Column(String)
    year = Column(String)
    rank = Column(Integer)
    ladder = Column(Float)
    log_gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom = Column(Float)
    generosity = Column(Float)
    corruption = Column(Float)
    positive_affect = Column(Float)
    negative_affect = Column(Float)
    well_being_inequality_1 = Column(Float)
    changes_happiness = Column(Float)
    common_name = Column(String)
    official_name = Column(String)
    cca2 = Column(String)
    cca3 = Column(String)
    capital = Column(String)
    region = Column(String)
    subregion = Column(String)
    latitude = Column(Float)
    longitude = Column(Float)
    demonym = Column(String)
    area_sqkm = Column(Float)
    nb_borders = Column(Integer)

# %%
Base.metadata.tables
# Out:
# immutabledict({'countries': Table('countries', MetaData(bind=None), Column('id', Integer(), table=<countries>, primary_key=True, nullable=False), Column('country', String(), table=<countries>), Column('year', String(), table=<countries>), Column('rank', Integer(), table=<countries>), Column('ladder', Float(), table=<countries>), Column('log_gdp_per_capita', Float(), table=<countries>), Column('social_support', Float(), table=<countries>), Column('healthy_life_expectancy', Float(), table=<countries>), Column('freedom', Float(), table=<countries>), Column('generosity', Float(), table=<countries>), Column('corruption', Float(), table=<countries>), Column('positive_affect', Float(), table=<countries>), Column('negative_affect', Float(), table=<countries>), Column('well_being_inequality_1', Float(), table=<countries>), Column('changes_happiness', Float(), table=<countries>), Column('common_name', String(), table=<countries>), Column('official_name', String(), table=<countries>), Column('cca2', String(), table=<countries>), Column('cca3', String(), table=<countries>), Column('capital', String(), table=<countries>), Column('region', String(), table=<countries>), Column('subregion', String(), table=<countries>), Column('latitude', Float(), table=<countries>), Column('longitude', Float(), table=<countries>), Column('demonym', String(), table=<countries>), Column('area_sqkm', Float(), table=<countries>), Column('nb_borders', Integer(), table=<countries>), schema=None)})

# %%
# Create our database engine
engine = create_engine('sqlite:///whr_countries.sqlite')

# %%
# Create our tables in the database
Base.metadata.create_all(engine)

# %%
# The ORM’s “handle” to the database is the Session.
from sqlalchemy.orm import Session
session = Session(engine)

# %%
# Load our csv file to be converted to sqlite
with open('whr_all_years.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        session.add(Country(country=row['country'], year=row['year'], rank=row['rank'], ladder=row['ladder'], log_gdp_per_capita=row['log_gdp_per_capita'],
                   social_support=row['social_support'], healthy_life_expectancy=row['healthy_life_expectancy'], freedom=row['freedom'],
                    generosity=row['generosity'], corruption=row['corruption'], positive_affect=row['positive_affect'],
                   negative_affect=row['negative_affect'], well_being_inequality_1=row['well_being_inequality_1'],
                    changes_happiness=row['changes_happiness'], common_name=row['common_name'], official_name=row['official_name'],
                    cca2=row['cca2'], cca3=row['cca3'], capital=row['capital'], region=row['region'], subregion=row['subregion'],
                    latitude=row['latitude'], longitude=row['longitude'], demonym=row['demonym'],
                   area_sqkm=row['area_sqkm'], nb_borders=row['nb_borders']))

# %%
engine.execute('select * from countries').fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Country object at 0x10465c978>, <__main__.Country object at 0x1047cf630>, <__main__.Country object at 0x1047cf908>, <__main__.Country object at 0x1047b7da0>, <__main__.Country object at 0x1047b7fd0>, <__main__.Country object at 0x1047bf780>, <__main__.Country object at 0x1047bfc50>, <__main__.Country object at 0x1047bffd0>, <__main__.Country object at 0x1047d5630>, <__main__.Country object at 0x1047d5b00>, <__main__.Country object at 0x1047d5f98>, <__main__.Country object at 0x1047d5978>, <__main__.Country object at 0x1047d5e10>, <__main__.Country object at 0x1047d4f60>, <__main__.Country object at 0x1047d4908>, <__main__.Country object at 0x1047d4e10>, <__main__.Country object at 0x1047d0f60>, <__main__.Country object at 0x1047d0908>, <__main__.Country object at 0x1047d0e10>, <__main__.Country object at 0x1047b8f60>, <__main__.Country object at 0x1047b8908>, <__main__.Country object at 0x1047b8e10>, <__main__.Country object at 0x1047bbf60>, <__main__.Country object at 0x1047bb908>, <__main__.Country object at 0x1047bbe10>, <__main__.Country object at 0x1047d1ef0>, <__main__.Country object at 0x1047d18d0>, <__main__.Country object at 0x1047d1da0>, <__main__.Country object at 0x1047c9e10>, <__main__.Country object at 0x1047c9828>, <__main__.Country object at 0x1047c9cc0>, <__main__.Country object at 0x1047c0ba8>, <__main__.Country object at 0x1047c0fd0>, <__main__.Country object at 0x1047c0ac8>, <__main__.Country object at 0x1047c0ef0>, <__main__.Country object at 0x1047d3c88>, <__main__.Country object at 0x1047d3fd0>, <__main__.Country object at 0x1047d3ba8>, <__main__.Country object at 0x1047d3ef0>, <__main__.Country object at 0x1047c5d68>, <__main__.Country object at 0x1047c5fd0>, <__main__.Country object at 0x1047c5c88>, <__main__.Country object at 0x1047c5898>, <__main__.Country object at 0x1047d6f28>, <__main__.Country object at 0x1047d6978>, <__main__.Country object at 0x1047d6dd8>, <__main__.Country object at 0x1047d7f28>, <__main__.Country object at 0x1047d78d0>, <__main__.Country object at 0x1047d7dd8>, <__main__.Country object at 0x1047d9f28>, <__main__.Country object at 0x1047d98d0>, <__main__.Country object at 0x1047d9dd8>, <__main__.Country object at 0x1047daf28>, <__main__.Country object at 0x1047da8d0>, <__main__.Country object at 0x1047dadd8>, <__main__.Country object at 0x1047dcf28>, <__main__.Country object at 0x1047dc8d0>, <__main__.Country object at 0x1047dcdd8>, <__main__.Country object at 0x1047decf8>, <__main__.Country object at 0x1047defd0>, <__main__.Country object at 0x1047debe0>, <__main__.Country object at 0x1047deef0>, <__main__.Country object at 0x1047dfe10>, <__main__.Country object at 0x1047dffd0>, <__main__.Country object at 0x1047dfcf8>, <__main__.Country object at 0x1047e2b00>, <__main__.Country object at 0x1047e2f28>, <__main__.Country object at 0x1047e29e8>, <__main__.Country object at 0x1047e2e10>, <__main__.Country object at 0x1047e3c50>, <__main__.Country object at 0x1047e3fd0>, <__main__.Country object at 0x1047e3b70>, <__main__.Country object at 0x1047e1b00>, <__main__.Country object at 0x1047e1f98>, <__main__.Country object at 0x1047e1a20>, <__main__.Country object at 0x1047e1eb8>, <__main__.Country object at 0x1047e6dd8>, <__main__.Country object at 0x1047e6860>, <__main__.Country object at 0x1047e6cf8>, <__main__.Country object at 0x1047e9c50>, <__main__.Country object at 0x1047e9fd0>, <__main__.Country object at 0x1047e9b00>, <__main__.Country object at 0x1047e8b00>, <__main__.Country object at 0x1047e8fd0>, <__main__.Country object at 0x1047e89b0>, <__main__.Country object at 0x1047e8e80>, <__main__.Country object at 0x1047ebe80>, <__main__.Country object at 0x1047eb898>, <__main__.Country object at 0x1047ebd30>, <__main__.Country object at 0x1047eed30>, <__main__.Country object at 0x1047eefd0>, <__main__.Country object at 0x1047eebe0>, <__main__.Country object at 0x1047edbe0>, <__main__.Country object at 0x1047edf60>, <__main__.Country object at 0x1047eda90 ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
# query the database
session.query(Country.country, Country.year, Country.rank).all()
# Out:
# [('Afghanistan', '2018', 136),
#  ('Afghanistan', '2017', 147),
#  ('Afghanistan', '2016', 120),
#  ('Afghanistan', '2015', 126),
#  ('Afghanistan', '2014', 143),
#  ('Afghanistan', '2013', 131),
#  ('Afghanistan', '2012', 136),
#  ('Afghanistan', '2011', 140),
#  ('Afghanistan', '2010', 84),
#  ('Afghanistan', '2009', 96),
#  ('Afghanistan', '2008', 105),
#  ('Albania', '2018', 92),
#  ('Albania', '2017', 108),
#  ('Albania', '2016', 109),
#  ('Albania', '2015', 109),
#  ('Albania', '2014', 97),
#  ('Albania', '2013', 102),
#  ('Albania', '2012', 64),
#  ('Albania', '2011', 45),
#  ('Albania', '2010', 67),
#  ('Albania', '2009', 48),
#  ('Albania', '2007', 78),
#  ('Algeria', '2018', 90),
#  ('Algeria', '2017', 82),
#  ('Algeria', '2016', 75),
#  ('Algeria', '2014', 35),
#  ('Algeria', '2012', 62),
#  ('Algeria', '2011', 70),
#  ('Algeria', '2010', 63),
#  ('Argentina', '2018', 59),
#  ('Argentina', '2017', 51),
#  ('Argentina', '2016', 28),
#  ('Argentina', '2015', 19),
#  ('Argentina', '2014', 24),
#  ('Argentina', '2013', 27),
#  ('Argentina', '2012', 28),
#  ('Argentina', '2011', 23),
#  ('Argentina', '2010', 28),
#  ('Argentina', '2009', 24),
#  ('Argentina', '2008', 30),
#  ('Argentina', '2007', 27),
#  ('Argentina', '2006', 14),
#  ('Armenia', '2018', 89),
#  ('Armenia', '2017', 125),
#  ('Armenia', '2016', 116),
#  ('Armenia', '2015', 117),
#  ('Armenia', '2014', 111),
#  ('Armenia', '2013', 109),
#  ('Armenia', '2012', 117),
#  ('Armenia', '2011', 125),
#  ('Armenia', '2010', 103),
#  ('Armenia', '2009', 104),
#  ('Armenia', '2008', 78),
#  ('Armenia', '2007', 69),
#  ('Armenia', '2006', 71),
#  ('Australia', '2018', 11),
#  ('Australia', '2017', 12),
#  ('Australia', '2016', 8),
#  ('Australia', '2015', 9),
#  ('Australia', '2014', 9),
#  ('Australia', '2013', 9),
#  ('Australia', '2012', 14),
#  ('Australia', '2011', 6),
#  ('Australia', '2010', 6),
#  ('Australia', '2008', 12),
#  ('Australia', '2007', 7),
#  ('Australia', '2005', 5),
#  ('Austria', '2018', 6),
#  ('Austria', '2017', 10),
#  ('Austria', '2016', 13),
#  ('Austria', '2015', 12),
#  ('Austria', '2014', 18),
#  ('Austria', '2013', 3),
#  ('Austria', '2012', 9),
#  ('Austria', '2011', 3),
#  ('Austria', '2010', 10),
#  ('Austria', '2008', 13),
#  ('Austria', '2006', 8),
#  ('Azerbaijan', '2018', 83),
#  ('Azerbaijan', '2017', 86),
#  ('Azerbaijan', '2016', 79),
#  ('Azerbaijan', '2015', 78),
#  ('Azerbaijan', '2014', 79),
#  ('Azerbaijan', '2013', 63),
#  ('Azerbaijan', '2012', 92),
#  ('Azerbaijan', '2011', 111),
#  ('Azerbaijan', '2010', 107),
#  ('Azerbaijan', '2009', 89),
#  ('Azerbaijan', '2008', 73),
#  ('Azerbaijan', '2007', 82),
#  ('Azerbaijan', '2006', 54),
#  ('Bangladesh', '2018', 110),
#  ('Bangladesh', '2017', 124),
#  ('Bangladesh', '2016', 103),
#  ('Bangladesh', '2015', 106),
#  ('Bangladesh', '2014', 103),
#  ('Bangladesh', '2013', 99),
#  ('Bangladesh', '2012', 99),
#  ('Bangladesh', '2011', 86),
#  ('Bangladesh', '2010', 81),
#  ('Bangladesh', '2009', 70),
#  ('Bangladesh', '2008', 65),
#  ('Bangladesh', '2007', 80),
#  ('Bangladesh', '2006', 70),
#  ('Belarus', '2018', 81),
#  ('Belarus', '2017', 74),
#  ('Belarus', '2016', 86),
#  ('Belarus', '2015', 59),
#  ('Belarus', '2014', 55),
#  ('Belarus', '2013', 50),
#  ('Belarus', '2012', 58),
#  ('Belarus', '2011', 73),
#  ('Belarus', '2010', 59),
#  ('Belarus', '2009', 45),
#  ('Belarus', '2008', 45),
#  ('Belarus', '2007', 40),
#  ('Belarus', '2006', 30),
#  ('Belgium', '2018', 19),
#  ('Belgium', '2017', 20),
#  ('Belgium', '2016', 16),
#  ('Belgium', '2015', 14),
#  ('Belgium', '2014', 20),
#  ('Belgium', '2013', 16),
#  ('Belgium', '2012', 20),
#  ('Belgium', '2011', 14),
#  ('Belgium', '2010', 18),
#  ('Belgium', '2008', 14),
#  ('Belgium', '2007', 10),
#  ('Belgium', '2005', 6),
#  ('Benin', '2018', 56),
#  ('Benin', '2017', 99),
#  ('Benin', '2016', 128),
#  ('Benin', '2015', 136),
#  ('Benin', '2014', 142),
#  ('Benin', '2013', 134),
#  ('Benin', '2012', 141),
#  ('Benin', '2011', 137),
#  ('Benin', '2008', 106),
#  ('Benin', '2006', 88),
#  ('Bolivia', '2018', 49),
#  ('Bolivia', '2017', 67),
#  ('Bolivia', '2016', 57),
#  ('Bolivia', '2015', 54),
#  ('Bolivia', '2014', 54),
#  ('Bolivia', '2013', 54),
#  ('Bolivia', '2012', 41),
#  ('Bolivia', '2011', 50),
#  ('Bolivia', '2010', 50),
#  ('Bolivia', '2009', 33),
#  ('Bolivia', '2008', 54),
#  ('Bolivia', '2007', 38),
#  ('Bolivia', '2006', 37),
#  ('Bosnia and Herzegovina', '2018', 52),
#  ('Bosnia and Herzegovina', '2017', 93),
#  ('Bosnia and Herzegovina', '2016', 85),
#  ('Bosnia and Herzegovina', '2015', 82),
#  ('Bosnia and Herzegovina', '2014', 78),
#  ('Bosnia and Herzegovina', '2013', 78),
#  ('Bosnia and Herzegovina', '2012', 96),
#  ('Bosnia and Herzegovina', '2011', 85),
#  ('Bosnia and Herzegovina', '2010', 90),
#  ('Bosnia and Herzegovina', '2009', 77),
#  ('Bosnia and Herzegovina', '2007', 65),
#  ('Botswana', '2018', 132),
#  ('Botswana', '2017', 140),
#  ('Botswana', '2016', 135),
#  ('Botswana', '2015', 132),
#  ('Botswana', '2014', 125),
#  ('Botswana', '2013', 114),
#  ('Botswana', '2012', 95),
#  ('Botswana', '2011', 145),
#  ('Botswana', '2010', 123),
#  ('Botswana', '2008', 46),
#  ('Botswana', '2006', 53),
#  ('Brazil', '2018', 40),
#  ('Brazil', '2017', 33),
#  ('Brazil', '2016', 29),
#  ('Brazil', '2015', 26),
#  ('Brazil', '2014', 16),
#  ('Brazil', '2013', 14),
#  ('Brazil', '2012', 24),
#  ('Brazil', '2011', 16),
#  ('Brazil', '2010', 20),
#  ('Brazil', '2009', 11),
#  ('Brazil', '2008', 24),
#  ('Brazil', '2007', 23),
#  ('Brazil', '2005', 13),
#  ('Bulgaria', '2018', 88),
#  ('Bulgaria', '2017', 90),
#  ('Bulgaria', '2016', 94),
#  ('Bulgaria', '2015', 96),
#  ('Bulgaria', '2014', 112),
#  ('Bulgaria', '2013', 116),
#  ('Bulgaria', '2012', 125),
#  ('Bulgaria', '2011', 136),
#  ('Bulgaria', '2010', 117),
#  ('Bulgaria', '2007', 98),
#  ('Burkina Faso', '2018', 93),
#  ('Burkina Faso', '2017', 107),
#  ('Burkina Faso', '2016', 121),
#  ('Burkina Faso', '2015', 115),
#  ('Burkina Faso', '2014', 138),
#  ('Burkina Faso', '2013', 136),
#  ('Burkina Faso', '2012', 132),
#  ('Burkina Faso', '2011', 104),
#  ('Burkina Faso', '2010', 115),
#  ('Burkina Faso', '2008', 102),
#  ('Burkina Faso', '2007', 96),
#  ('Burkina Faso', '2006', 80),
#  ('Burundi', '2018', 128),
#  ('Burundi', '2014', 144),
#  ('Burundi', '2011', 143),
#  ('Burundi', '2009', 111),
#  ('Burundi', '2008', 107),
#  ('Cambodia', '2018', 87),
#  ('Cambodia', '2017', 112),
#  ('Cambodia', '2016', 111),
#  ('Cambodia', '2015', 122),
#  ('Cambodia', '2014', 130),
#  ('Cambodia', '2013', 128),
#  ('Cambodia', '2012', 134),
#  ('Cambodia', '2011', 130),
#  ('Cambodia', '2010', 111),
#  ('Cambodia', '2009', 105),
#  ('Cambodia', '2008', 88),
#  ('Cambodia', '2007', 91),
#  ('Cambodia', '2006', 86),
#  ('Cameroon', '2018', 78),
#  ('Cameroon', '2017', 94),
#  ('Cameroon', '2016', 96),
#  ('Cameroon', '2015', 88),
#  ('Cameroon', '2014', 120),
#  ('Cameroon', '2013', 110),
#  ('Cameroon', '2012', 122),
#  ('Cameroon', '2011', 118),
#  ('Cameroon', '2010', 96),
#  ('Cameroon', '2009', 85),
#  ('Cameroon', '2008', 95),
#  ('Cameroon', '2007', 88),
#  ('Cameroon', '2006', 77),
#  ('Canada', '2018', 12),
#  ('Canada', '2017', 7),
#  ('Canada', '2016', 9),
#  ('Canada', '2015', 7),
#  ('Canada', '2014', 8),
#  ('Canada', '2013', 1),
#  ('Canada', '2012', 7),
#  ('Canada', '2011', 5),
#  ('Canada', '2010', 2),
#  ('Canada', '2009', 4),
#  ('Canada', '2008', 7),
#  ('Canada', '2007', 4),
#  ('Canada', '2005', 3),
#  ('Chad', '2018', 111),
#  ('Chad', '2017', 113),
#  ('Chad', '2016', 125),
#  ('Chad', '2015', 119),
#  ('Chad', '2014', 140),
#  ('Chad', '2013', 133),
#  ('Chad', '2012', 128),
#  ('Chad', '2011', 120),
#  ('Chad', '2010', 121),
#  ('Chad', '2009', 112),
#  ('Chad', '2008', 82),
#  ('Chad', '2007', 95),
#  ('Chad', '2006', 87),
#  ('Chile', '2018', 28),
#  ('Chile', '2017', 35),
#  ('Chile', '2016', 24),
#  ('Chile', '2015', 27),
#  ('Chile', '2014', 21),
#  ('Chile', '2013', 21),
#  ('Chile', '2012', 27),
#  ('Chile', '2011', 32),
#  ('Chile', '2010', 26),
#  ('Chile', '2009', 21),
#  ('Chile', '2008', 34),
#  ('Chile', '2007', 35),
#  ('Chile', '2006', 20),
#  ('China', '2018', 86),
#  ('China', '2017', 92),
#  ('China', '2016', 77),
#  ('China', '2015', 74),
#  ('China', '2014', 81),
#  ('China', '2013', 71),
#  ('China', '2012', 82),
#  ('China', '2011', 80),
#  ('China', '2010', 92),
#  ('China', '2009', 94),
#  ('China', '2008', 71),
#  ('China', '2007', 70),
#  ('China', '2006', 65),
#  ('Colombia', '2018', 46),
#  ('Colombia', '2017', 45),
#  ('Colombia', '2016', 32),
#  ('Colombia', '2015', 31),
#  ('Colombia', '2014', 32),
#  ('Colombia', '2013', 26),
#  ('Colombia', '2012', 31),
#  ('Colombia', '2011', 35),
#  ('Colombia', '2010', 29),
#  ('Colombia', '2009', 29),
#  ('Colombia', '2008', 29),
#  ('Colombia', '2007', 26),
#  ('Colombia', '2006', 21),
#  ('Comoros', '2018', 126),
#  ('Comoros', '2012', 131),
#  ('Comoros', '2011', 138),
#  ('Comoros', '2010', 118),
#  ('Comoros', '2009', 113),
#  ('Congo (Brazzaville)', '2018', 66),
#  ('Congo (Brazzaville)', '2017', 97),
#  ('Congo (Brazzaville)', '2016', 123),
#  ('Congo (Brazzaville)', '2015', 104),
#  ('Congo (Brazzaville)', '2014', 124),
#  ('Congo (Brazzaville)', '2013', 117),
#  ('Congo (Brazzaville)', '2012', 133),
#  ('Congo (Brazzaville)', '2011', 116),
#  ('Congo (Brazzaville)', '2008', 104),
#  ('Costa Rica', '2018', 13),
#  ('Costa Rica', '2017', 13),
#  ('Costa Rica', '2016', 12),
#  ('Costa Rica', '2015', 16),
#  ('Costa Rica', '2014', 10),
#  ('Costa Rica', '2013', 13),
#  ('Costa Rica', '2012', 11),
#  ('Costa Rica', '2011', 10),
#  ('Costa Rica', '2010', 11),
#  ('Costa Rica', '2009', 2),
#  ('Costa Rica', '2008', 19),
#  ('Costa Rica', '2007', 6),
#  ('Costa Rica', '2006', 9),
#  ('Croatia', '2018', 64),
#  ('Croatia', '2017', 77),
#  ('Croatia', '2016', 72),
#  ('Croatia', '2015', 75),
#  ('Croatia', '2014', 72),
#  ('Croatia', '2013', 49),
#  ('Croatia', '2012', 40),
#  ('Croatia', '2011', 66),
#  ('Croatia', '2010', 55),
#  ('Croatia', '2009', 52),
#  ('Croatia', '2007', 30),
#  ('Cyprus', '2018', 34),
#  ('Cyprus', '2017', 50),
#  ('Cyprus', '2016', 56),
#  ('Cyprus', '2015', 69),
#  ('Cyprus', '2014', 64),
#  ('Cyprus', '2013', 64),
#  ('Cyprus', '2012', 37),
#  ('Cyprus', '2011', 25),
#  ('Cyprus', '2010', 30),
#  ('Cyprus', '2009', 17),
#  ('Cyprus', '2006', 15),
#  ('Czech Republic', '2018', 15),
#  ('Czech Republic', '2017', 21),
#  ('Czech Republic', '2016', 22),
#  ('Czech Republic', '2015', 24),
#  ('Czech Republic', '2014', 29),
#  ('Czech Republic', '2013', 22),
#  ('Czech Republic', '2012', 32),
#  ('Czech Republic', '2011', 37),
#  ('Czech Republic', '2010', 34),
#  ('Czech Republic', '2007', 19),
#  ('Czech Republic', '2005', 17),
#  ('Denmark', '2018', 2),
#  ('Denmark', '2017', 2),
#  ('Denmark', '2016', 3),
#  ('Denmark', '2015', 3),
#  ('Denmark', '2014', 1),
#  ('Denmark', '2013', 2),
#  ('Denmark', '2012', 5),
#  ('Denmark', '2011', 1),
#  ('Denmark', '2010', 1),
#  ('Denmark', '2009', 1),
#  ('Denmark', '2008', 1),
#  ('Denmark', '2007', 1),
#  ('Denmark', '2005', 1),
#  ('Dominican Republic', '2018', 70),
#  ('Dominican Republic', '2017', 70),
#  ('Dominican Republic', '2016', 83),
#  ('Dominican Republic', '2015', 87),
#  ('Dominican Republic', '2014', 71),
#  ('Dominican Republic', '2013', 83),
#  ('Dominican Republic', '2012', 97),
#  ('Dominican Republic', '2011', 64),
#  ('Dominican Republic', '2010', 85),
#  ('Dominican Republic', '2009', 53),
#  ('Dominican Republic', '2008', 72),
#  ('Dominican Republic', '2007', 59),
#  ('Dominican Republic', '2006', 44),
#  ('Ecuador', '2018', 42),
#  ('Ecuador', '2017', 60),
#  ('Ecuador', '2016', 37),
#  ('Ecuador', '2015', 47),
#  ('Ecuador', '2014', 49),
#  ('Ecuador', '2013', 40),
#  ('Ecuador', '2012', 47),
#  ('Ecuador', '2011', 46),
#  ('Ecuador', '2010', 46),
#  ('Ecuador', '2009', 36),
#  ('Ecuador', '2008', 53),
#  ('Ecuador', '2007', 62),
#  ('Ecuador', '2006', 47),
#  ('Egypt', '2018', 125),
#  ('Egypt', '2017', 136),
#  ('Egypt', '2016', 104),
#  ('Egypt', '2015', 101),
#  ('Egypt', '2014', 94),
#  ('Egypt', '2013', 132),
#  ('Egypt', '2012', 126),
#  ('Egypt', '2011', 129),
#  ('Egypt', '2010', 89),
#  ('Egypt', '2009', 72),
#  ('Egypt', '2008', 81),
#  ('Egypt', '2007', 42),
#  ('Egypt', '2005', 25),
#  ('El Salvador', '2018', 36),
#  ('El Salvador', '2017', 32),
#  ('El Salvador', '2016', 36),
#  ('El Salvador', '2015', 41),
#  ('El Salvador', '2014', 53),
#  ('El Salvador', '2013', 35),
#  ('El Salvador', '2012', 48),
#  ('El Salvador', '2011', 108),
#  ('El Salvador', '2010', 24),
#  ('El Salvador', '2009', 16),
#  ('El Salvador', '2008', 55),
#  ('El Salvador', '2007', 48),
#  ('El Salvador', '2006', 29),
#  ('Estonia', '2018', 43),
#  ('Estonia', '2017', 54),
#  ('Estonia', '2016', 62),
#  ('Estonia', '2015', 61),
#  ('Estonia', '2014', 67),
#  ('Estonia', '2013', 67),
#  ('Estonia', '2012', 71),
#  ('Estonia', '2011', 60),
#  ('Estonia', '2009', 69),
#  ('Estonia', '2008', 47),
#  ('Estonia', '2007', 47),
#  ('Estonia', '2006', 36),
#  ('Ethiopia', '2018', 115),
#  ('Ethiopia', '2017', 127),
#  ('Ethiopia', '2016', 117),
#  ('Ethiopia', '2015', 111),
#  ('Ethiopia', '2014', 108),
#  ('Ethiopia', '2013', 105),
#  ('Ethiopia', '2012', 109),
#  ('Finland', '2018', 1),
#  ('Finland', '2017', 1),
#  ('Finland', '2016', 1),
#  ('Finland', '2015', 5),
#  ('Finland', '2014', 5),
#  ('Finland', '2013', 5),
#  ('Finland', '2012', 8),
#  ('Finland', '2011', 8),
#  ('Finland', '2010', 7),
#  ('Finland', '2008', 2),
#  ('Finland', '2006', 1),
#  ('France', '2018', 21),
#  ('France', '2017', 23),
#  ('France', '2016', 26),
#  ('France', '2015', 34),
#  ('France', '2014', 30),
#  ('France', '2013', 24),
#  ('France', '2012', 25),
#  ('France', '2011', 18),
#  ('France', '2010', 21),
#  ('France', '2009', 28),
#  ('France', '2008', 15),
#  ('France', '2006', 11),
#  ('France', '2005', 9),
#  ('Gabon', '2018', 100),
#  ('Gabon', '2017', 101),
#  ('Gabon', '2016', 95),
#  ('Gabon', '2015', 105),
#  ('Gabon', '2014', 128),
#  ('Gabon', '2013', 123),
#  ('Gabon', '2012', 130),
#  ('Gabon', '2011', 124),
#  ('Gambia', '2018', 94),
#  ('Gambia', '2017', 129),
#  ('Georgia', '2018', 103),
#  ('Georgia', '2017', 117),
#  ('Georgia', '2016', 112),
#  ('Georgia', '2015', 123),
#  ('Georgia', '2014', 118),
#  ('Georgia', '2013', 108),
#  ('Georgia', '2012', 121),
#  ('Georgia', '2011', 127),
#  ('Georgia', '2010', 113),
#  ('Georgia', '2009', 110),
#  ('Georgia', '2008', 99),
#  ('Georgia', '2007', 99),
#  ('Georgia', '2006', 84),
#  ('Germany', '2018', 14),
#  ('Germany', '2017', 15),
#  ('Germany', '2016', 17),
#  ('Germany', '2015', 13),
#  ('Germany', '2014', 17),
#  ('Germany', '2013', 17),
#  ('Germany', '2012', 23),
#  ('Germany', '2011', 27),
#  ('Germany', '2010', 25),
#  ('Germany', '2009', 18),
#  ('Germany', '2008', 26),
#  ('Germany', '2007', 21),
#  ('Germany', '2005', 14),
#  ('Greece', '2018', 71),
#  ('Greece', '2017', 87),
#  ('Greece', '2016', 78),
#  ('Greece', '2015', 62),
#  ('Greece', '2014', 100),
#  ('Greece', '2013', 95),
#  ('Greece', '2012', 81),
#  ('Greece', '2011', 69),
#  ('Greece', '2010', 48),
#  ('Greece', '2009', 34),
#  ('Greece', '2007', 16),
#  ('Greece', '2005', 19),
#  ('Guatemala', '2018', 22),
#  ('Guatemala', '2017', 34),
#  ('Guatemala', '2016', 30),
#  ('Guatemala', '2015', 29),
#  ('Guatemala', '2014', 28),
#  ('Guatemala', '2013', 42),
#  ('Guatemala', '2012', 52),
#  ('Guatemala', '2011', 52),
#  ('Guatemala', '2010', 33),
#  ('Guatemala', '2009', 22),
#  ('Guatemala', '2008', 27),
#  ('Guatemala', '2007', 22),
#  ('Guatemala', '2006', 24),
#  ('Guinea', '2018', 77),
#  ('Guinea', '2017', 98),
#  ('Guinea', '2016', 134),
#  ('Guinea', '2015', 139),
#  ('Guinea', '2014', 141),
#  ('Guinea', '2013', 119),
#  ('Guinea', '2012', 138),
#  ('Guinea', '2011', 134),
#  ('Haiti', '2018', 130),
#  ('Haiti', '2017', 137),
#  ('Haiti', '2016', 138),
#  ('Haiti', '2015', 138),
#  ('Haiti', '2014', 129),
#  ('Haiti', '2013', 100),
#  ('Haiti', '2012', 115),
#  ('Haiti', '2011', 100),
#  ('Haiti', '2010', 119),
#  ('Haiti', '2008', 103),
#  ('Haiti', '2006', 81),
#  ('Honduras', '2018', 50),
#  ('Honduras', '2017', 52),
#  ('Honduras', '2016', 61),
#  ('Honduras', '2015', 97),
#  ('Honduras', '2014', 88),
#  ('Honduras', '2013', 96),
#  ('Honduras', '2012', 107),
#  ('Honduras', '2011', 89),
#  ('Honduras', '2010', 45),
#  ('Honduras', '2009', 35),
#  ('Honduras', '2008', 48),
#  ('Honduras', '2007', 58),
#  ('Honduras', '2006', 35),
#  ('India', '2018', 127),
#  ('India', '2017', 133),
#  ('India', '2016', 122),
#  ('India', '2015', 118),
#  ('India', '2014', 113),
#  ('India', '2013', 106),
#  ('India', '2012', 98),
#  ('India', '2011', 113),
#  ('India', '2010', 78),
#  ('India', '2009', 90),
#  ('India', '2008', 58),
#  ('India', '2007', 61),
#  ('India', '2006', 38),
#  ('Indonesia', '2018', 73),
#  ('Indonesia', '2017', 91),
#  ('Indonesia', '2016', 87),
#  ('Indonesia', '2015', 89),
#  ('Indonesia', '2014', 65),
#  ('Indonesia', '2013', 68),
#  ('Indonesia', '2012', 70),
#  ('Indonesia', '2011', 77),
#  ('Indonesia', '2010', 64),
#  ('Indonesia', '2009', 50),
#  ('Indonesia', '2008', 74),
#  ('Indonesia', '2007', 57),
#  ('Indonesia', '2006', 49),
#  ('Iran', '2018', 119),
#  ('Iran', '2017', 104),
#  ('Iran', '2016', 100),
#  ('Iran', '2015', 102),
#  ('Iran', '2014', 102),
#  ('Iran', '2013', 75),
#  ('Iran', '2012', 106),
#  ('Iran', '2011', 106),
#  ('Iran', '2008', 60),
#  ('Iran', '2007', 46),
#  ('Iran', '2005', 22),
#  ('Ireland', '2018', 16),
#  ('Ireland', '2017', 17),
#  ('Ireland', '2016', 14),
#  ('Ireland', '2015', 17),
#  ('Ireland', '2014', 14),
#  ('Ireland', '2013', 20),
#  ('Ireland', '2012', 18),
#  ('Ireland', '2011', 17),
#  ('Ireland', '2010', 12),
#  ('Ireland', '2009', 9),
#  ('Ireland', '2008', 5),
#  ('Ireland', '2006', 7),
#  ('Israel', '2018', 17),
#  ('Israel', '2017', 9),
#  ('Israel', '2016', 11),
#  ('Israel', '2015', 11),
#  ('Israel', '2014', 4),
#  ('Israel', '2013', 10),
#  ('Israel', '2012', 15),
#  ('Israel', '2011', 4),
#  ('Israel', '2010', 8),
#  ('Israel', '2009', 5),
#  ('Israel', '2008', 11),
#  ('Israel', '2007', 13),
#  ('Israel', '2006', 6),
#  ('Italy', '2018', 25),
#  ('Italy', '2017', 40),
#  ('Italy', '2016', 47),
#  ('Italy', '2015', 52),
#  ('Italy', '2014', 45),
#  ('Italy', '2013', 41),
#  ('Italy', '2012', 53),
#  ('Italy', '2011', 41),
#  ('Italy', '2010', 31),
#  ('Italy', '2009', 25),
#  ('Italy', '2008', 22),
#  ('Italy', '2007', 17),
#  ('Italy', '2005', 12),
#  ('Ivory Coast', '2018', 76),
#  ('Ivory Coast', '2017', 96),
#  ('Ivory Coast', '2016', 105),
#  ('Ivory Coast', '2015', 114),
#  ('Ivory Coast', '2014', 137),
#  ('Ivory Coast', '2013', 124),
#  ('Ivory Coast', '2009', 102),
#  ('Japan', '2018', 58),
#  ('Japan', '2017', 56),
#  ('Japan', '2016', 46),
#  ('Japan', '2015', 51),
#  ('Japan', '2014', 51),
#  ('Japan', '2013', 45),
#  ('Japan', '2012', 45),
#  ('Japan', '2011', 39),
#  ('Japan', '2010', 41),
#  ('Japan', '2009', 39),
#  ('Japan', '2008', 31),
#  ('Japan', '2007', 24),
#  ('Japan', '2005', 16),
#  ('Jordan', '2018', 107),
#  ('Jordan', '2017', 100),
#  ('Jordan', '2016', 81),
#  ('Jordan', '2015', 70),
#  ('Jordan', '2014', 73),
#  ('Jordan', '2013', 73),
#  ('Jordan', '2012', 77),
#  ('Jordan', '2011', 59),
#  ('Jordan', '2010', 58),
#  ('Jordan', '2009', 37),
#  ('Jordan', '2008', 70),
#  ('Jordan', '2007', 41),
#  ('Jordan', '2005', 18),
#  ('Kazakhstan', '2018', 44),
#  ('Kazakhstan', '2017', 58),
#  ('Kazakhstan', '2016', 66),
#  ('Kazakhstan', '2015', 48),
#  ('Kazakhstan', '2014', 46),
#  ('Kazakhstan', '2013', 51),
#  ('Kazakhstan', '2012', 57),
#  ('Kazakhstan', '2011', 53),
#  ('Kazakhstan', '2010', 60),
#  ('Kazakhstan', '2009', 55),
#  ('Kazakhstan', '2008', 32),
#  ('Kazakhstan', '2007', 34),
#  ('Kazakhstan', '2006', 32),
#  ('Kenya', '2018', 105),
#  ('Kenya', '2017', 115),
#  ('Kenya', '2016', 114),
#  ('Kenya', '2015', 116),
#  ('Kenya', '2014', 93),
#  ('Kenya', '2013', 122),
#  ('Kenya', '2012', 111),
#  ('Kenya', '2011', 119),
#  ('Kenya', '2010', 106),
#  ('Kenya', '2009', 99),
#  ('Kenya', '2008', 101),
#  ('Kenya', '2007', 81),
#  ('Kenya', '2006', 72),
#  ('Kosovo', '2018', 29),
#  ('Kosovo', '2017', 46),
#  ('Kosovo', '2016', 58),
#  ('Kosovo', '2015', 86),
#  ('Kosovo', '2014', 89),
#  ('Kosovo', '2013', 39),
#  ('Kosovo', '2012', 60),
#  ('Kosovo', '2011', 98),
#  ('Kosovo', '2010', 68),
#  ('Kosovo', '2009', 38),
#  ('Kosovo', '2008', 42),
#  ('Kosovo', '2007', 56),
#  ('Kyrgyzstan', '2018', 74),
#  ('Kyrgyzstan', '2017', 68),
#  ('Kyrgyzstan', '2016', 93),
#  ('Kyrgyzstan', '2015', 93),
#  ('Kyrgyzstan', '2014', 77),
#  ('Kyrgyzstan', '2013', 65),
#  ('Kyrgyzstan', '2012', 74),
#  ('Kyrgyzstan', '2011', 93),
#  ('Kyrgyzstan', '2010', 77),
#  ('Kyrgyzstan', '2009', 71),
#  ('Kyrgyzstan', '2008', 75),
#  ('Kyrgyzstan', '2007', 75),
#  ('Kyrgyzstan', '2006', 61),
#  ('Laos', '2018', 98),
#  ('Laos', '2017', 110),
#  ('Laos', '2012', 94),
#  ('Laos', '2011', 110),
#  ('Laos', '2008', 66),
#  ('Laos', '2007', 45),
#  ('Laos', '2006', 45),
#  ('Latvia', '2018', 51),
#  ('Latvia', '2017', 53),
#  ('Latvia', '2016', 48),
#  ('Latvia', '2015', 50),
#  ('Latvia', '2014', 61),
#  ('Latvia', '2013', 81),
#  ('Latvia', '2012', 80),
#  ('Latvia', '2011', 87),
#  ('Latvia', '2009', 86),
#  ('Latvia', '2008', 57),
#  ('Latvia', '2007', 77),
#  ('Latvia', '2006', 58),
#  ('Lebanon', '2018', 84),
#  ('Lebanon', '2017', 88),
#  ('Lebanon', '2016', 82),
#  ('Lebanon', '2015', 76),
#  ('Lebanon', '2014', 80),
#  ('Lebanon', '2013', 85),
#  ('Lebanon', '2012', 108),
#  ('Lebanon', '2011', 76),
#  ('Lebanon', '2010', 75),
#  ('Lebanon', '2009', 63),
#  ('Lebanon', '2008', 85),
#  ('Lebanon', '2006', 60),
#  ('Lebanon', '2005', 21),
#  ('Liberia', '2018', 121),
#  ('Liberia', '2017', 119),
#  ('Liberia', '2016', 137),
#  ('Liberia', '2015', 143),
#  ('Liberia', '2014', 104),
#  ('Liberia', '2010', 108),
#  ('Liberia', '2008', 98),
#  ('Liberia', '2007', 100),
#  ('Libya', '2018', 67),
#  ('Libya', '2017', 66),
#  ('Libya', '2016', 71),
#  ('Libya', '2015', 63),
#  ('Libya', '2012', 59),
#  ('Lithuania', '2018', 33),
#  ('Lithuania', '2017', 37),
#  ('Lithuania', '2016', 52),
#  ('Lithuania', '2015', 60),
#  ('Lithuania', '2014', 42),
#  ('Lithuania', '2013', 59),
#  ('Lithuania', '2012', 56),
#  ('Lithuania', '2011', 63),
#  ('Lithuania', '2010', 72),
#  ('Lithuania', '2009', 51),
#  ('Lithuania', '2008', 41),
#  ('Lithuania', '2007', 31),
#  ('Lithuania', '2006', 23),
#  ('Luxembourg', '2018', 9),
#  ('Luxembourg', '2017', 16),
#  ('Luxembourg', '2016', 15),
#  ('Luxembourg', '2015', 18),
#  ('Luxembourg', '2014', 19),
#  ('Luxembourg', '2013', 15),
#  ('Luxembourg', '2012', 19),
#  ('Luxembourg', '2011', 15),
#  ('Luxembourg', '2010', 15),
#  ('Luxembourg', '2009', 13),
#  ('Macedonia', '2018', 80),
#  ('Macedonia', '2017', 83),
#  ('Macedonia', '2016', 74),
#  ('Macedonia', '2015', 91),
#  ('Macedonia', '2014', 82),
#  ('Macedonia', '2013', 72),
#  ('Macedonia', '2012', 104),
#  ('Macedonia', '2011', 94),
#  ('Macedonia', '2010', 110),
#  ('Macedonia', '2009', 95),
#  ('Macedonia', '2007', 83),
#  ('Madagascar', '2018', 122),
#  ('Madagascar', '2017', 132),
#  ('Madagascar', '2016', 133),
#  ('Madagascar', '2015', 137),
#  ('Madagascar', '2014', 135),
#  ('Madagascar', '2013', 121),
#  ('Madagascar', '2012', 139),
#  ('Madagascar', '2011', 121),
#  ('Madagascar', '2008', 80),
#  ('Madagascar', '2006', 75),
#  ('Malawi', '2018', 134),
#  ('Malawi', '2017', 142),
#  ('Malawi', '2016', 136),
#  ('Malawi', '2015', 130),
#  ('Malawi', '2014', 106),
#  ('Malawi', '2013', 115),
#  ('Malawi', '2012', 120),
#  ('Malawi', '2011', 135),
#  ('Malawi', '2009', 68),
#  ('Malawi', '2007', 68),
#  ('Malawi', '2006', 78),
#  ('Malaysia', '2018', 72),
#  ('Malaysia', '2015', 36),
#  ('Malaysia', '2014', 47),
#  ('Malaysia', '2013', 53),
#  ('Malaysia', '2012', 49),
#  ('Malaysia', '2011', 48),
#  ('Malaysia', '2010', 57),
#  ('Malaysia', '2009', 56),
#  ('Malaysia', '2008', 33),
#  ('Malaysia', '2007', 25),
#  ('Malaysia', '2006', 22),
#  ('Mali', '2018', 112),
#  ('Mali', '2017', 103),
#  ('Mali', '2016', 127),
#  ('Mali', '2015', 110),
#  ('Mali', '2014', 126),
#  ('Mali', '2013', 127),
#  ('Mali', '2012', 118),
#  ('Mali', '2011', 112),
#  ('Mali', '2010', 120),
#  ('Mali', '2009', 108),
#  ('Mali', '2008', 100),
#  ('Mali', '2006', 74),
#  ('Malta', '2018', 18),
#  ('Malta', '2017', 22),
#  ('Malta', '2016', 23),
#  ('Malta', '2015', 22),
#  ('Malta', '2014', 33),
#  ('Malta', '2013', 33),
#  ('Malta', '2012', 46),
#  ('Malta', '2011', 40),
#  ('Malta', '2010', 51),
#  ('Malta', '2009', 26),
#  ('Mauritania', '2018', 118),
#  ('Mauritania', '2017', 105),
#  ('Mauritania', '2016', 110),
#  ('Mauritania', '2015', 128),
#  ('Mauritania', '2014', 110),
#  ('Mauritania', '2013', 112),
#  ('Mauritania', '2012', 101),
#  ('Mauritania', '2011', 105),
#  ('Mauritania', '2010', 82),
#  ('Mauritania', '2009', 91),
#  ('Mauritania', '2008', 96),
#  ('Mauritania', '2007', 94),
#  ('Mauritius', '2018', 53),
#  ('Mauritius', '2017', 43),
#  ('Mauritius', '2016', 63),
#  ('Mauritius', '2014', 63),
#  ('Mauritius', '2011', 61),
#  ('Mexico', '2018', 24),
#  ('Mexico', '2017', 27),
#  ('Mexico', '2016', 20),
#  ('Mexico', '2015', 37),
#  ('Mexico', '2014', 23),
#  ('Mexico', '2013', 6),
#  ('Mexico', '2012', 10),
#  ('Mexico', '2011', 20),
#  ('Mexico', '2010', 23),
#  ('Mexico', '2009', 12),
#  ('Mexico', '2008', 20),
#  ('Mexico', '2007', 18),
#  ('Mexico', '2005', 15),
#  ('Moldova', '2018', 61),
#  ('Moldova', '2017', 78),
#  ('Moldova', '2016', 64),
#  ('Moldova', '2015', 42),
#  ('Moldova', '2014', 50),
#  ('Moldova', '2013', 56),
#  ('Moldova', '2012', 43),
#  ('Moldova', '2011', 49),
#  ('Moldova', '2010', 56),
#  ('Moldova', '2009', 46),
#  ('Moldova', '2008', 43),
#  ('Moldova', '2007', 72),
#  ('Moldova', '2006', 43),
#  ('Mongolia', '2018', 69),
#  ('Mongolia', '2017', 79),
#  ('Mongolia', '2016', 90),
#  ('Mongolia', '2015', 90),
#  ('Mongolia', '2014', 96),
#  ('Mongolia', '2013', 90),
#  ('Mongolia', '2012', 93),
#  ('Mongolia', '2011', 81),
#  ('Mongolia', '2010', 95),
#  ('Mongolia', '2008', 87),
#  ('Mongolia', '2007', 79),
#  ('Montenegro', '2018', 62),
#  ('Montenegro', '2017', 69),
#  ('Montenegro', '2016', 80),
#  ('Montenegro', '2015', 80),
#  ('Montenegro', '2014', 76),
#  ('Montenegro', '2013', 82),
#  ('Montenegro', '2012', 73),
#  ('Montenegro', '2011', 74),
#  ('Montenegro', '2010', 62),
#  ('Montenegro', '2009', 83),
#  ('Montenegro', '2007', 55),
#  ('Morocco', '2018', 96),
#  ('Morocco', '2017', 81),
#  ('Morocco', '2016', 73),
#  ('Morocco', '2015', 77),
#  ('Morocco', '2013', 77),
#  ('Morocco', '2012', 90),
#  ('Morocco', '2011', 79),
#  ('Morocco', '2010', 100),
#  ('Mozambique', '2018', 106),
#  ('Mozambique', '2017', 126),
#  ('Mozambique', '2015', 112),
#  ('Mozambique', '2011', 88),
#  ('Mozambique', '2008', 79),
#  ('Mozambique', '2007', 71),
#  ('Mozambique', '2006', 63),
#  ('Myanmar', '2018', 113),
#  ('Myanmar', '2017', 128),
#  ('Myanmar', '2016', 101),
#  ('Myanmar', '2015', 121),
#  ('Myanmar', '2014', 98),
#  ('Myanmar', '2013', 113),
#  ('Myanmar', '2012', 114),
#  ('Namibia', '2018', 99),
#  ('Namibia', '2017', 118),
#  ('Namibia', '2014', 105),
#  ('Namibia', '2007', 66),
#  ('Nepal', '2018', 95),
#  ('Nepal', '2017', 102),
#  ('Nepal', '2016', 88),
#  ('Nepal', '2015', 100),
#  ('Nepal', '2014', 90),
#  ('Nepal', '2013', 101),
#  ('Nepal', '2012', 123),
#  ('Nepal', '2011', 141),
#  ('Nepal', '2010', 104),
#  ('Nepal', '2009', 78),
#  ('Nepal', '2008', 89),
#  ('Nepal', '2007', 73),
#  ('Nepal', '2006', 64),
#  ('Netherlands', '2018', 4),
#  ('Netherlands', '2017', 6),
#  ('Netherlands', '2016', 4),
#  ('Netherlands', '2015', 8),
#  ('Netherlands', '2014', 6),
#  ('Netherlands', '2013', 8),
#  ('Netherlands', '2012', 6),
#  ('Netherlands', '2011', 2),
#  ('Netherlands', '2010', 4),
#  ('Netherlands', '2008', 3),
#  ('Netherlands', '2007', 5),
#  ('Netherlands', '2005', 2),
#  ('New Zealand', '2018', 7),
#  ('New Zealand', '2017', 8),
#  ('New Zealand', '2016', 10),
#  ('New Zealand', '2015', 6),
#  ('New Zealand', '2014', 7),
#  ('New Zealand', '2013', 11),
#  ('New Zealand', '2012', 12),
#  ('New Zealand', '2011', 11),
#  ('New Zealand', '2010', 13),
#  ('New Zealand', '2008', 8),
#  ('New Zealand', '2007', 2),
#  ('New Zealand', '2006', 4),
#  ('Nicaragua', '2018', 57),
#  ('Nicaragua', '2017', 25),
#  ('Nicaragua', '2016', 41),
#  ('Nicaragua', '2015', 49),
#  ('Nicaragua', '2014', 36),
#  ('Nicaragua', '2013', 55),
#  ('Nicaragua', '2012', 69),
#  ('Nicaragua', '2011', 65),
#  ('Nicaragua', '2010', 52),
#  ('Nicaragua', '2009', 58),
#  ('Nicaragua', '2008', 63),
#  ('Nicaragua', '2007', 64),
#  ('Nicaragua', '2006', 67),
#  ('Niger', '2018', 85),
#  ...]

# %% [markdown]
# # TESTING for building whr_table app

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///whr_countries.sqlite")

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['countries']

# %%
Countries = Base.classes.countries

# %%
session = Session(engine)

# %%
import os
import pandas as pd
import numpy as np

# %%
sel = [
    Countries.rank,
    Countries.country,
    Countries.year,
    Countries.ladder,
    Countries.well_being_inequality_1,
    Countries.positive_affect,
    Countries.negative_affect,
    Countries.social_support,
    Countries.freedom,
    Countries.corruption,
    Countries.generosity,
    Countries.log_gdp_per_capita,
    Countries.healthy_life_expectancy
    ]

results = session.query(*sel).all()

# %%
country = {}
countries = []

# %%
for result in results:
    country["rank"] = result[0]
    country["country"] = result[1]
    country["year"] = result[2]
    country["ladder"] = result[3]
    country["well_being_inequality_1"] = result[4]
    country["positive_affect"] = result[5]
    country["negative_affect"] = result[6]
    country["social_support"] = result[7]
    country["freedom"] = result[8]
    country["corruption"] = result[9]
    country["generosity"] = result[10]
    country["log_gdp_per_capita"] = result[11]
    country["healthy_life_expectancy"] = result[12]
    countries.append(country)

# %%
print(countries)
# Out:
# [{'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_capita': 9.68, 'healthy_life_expectancy': 68.44}, {'rank': 33, 'country': 'Cuba', 'year': '2006', 'ladder': 5.42, 'well_being_inequality_1': 2.13, 'positive_affect': 0.65, 'negative_affect': 0.28, 'social_support': 0.97, 'freedom': 0.28, 'corruption': 0.5, 'generosity': 0.0, 'log_gdp_per_cap ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e540e8ab7b06> in <module>
# ----> 1 jsonify(countries)
#
# NameError: name 'jsonify' is not defined
